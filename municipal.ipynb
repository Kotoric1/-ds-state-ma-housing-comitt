# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./MA_geographic.csv")

# %%
df = df.sort_values('Normalize', ascending=False)
df = df.reset_index(drop=True)
muni = df['Muni']

# %%
plt.scatter(df['Normalize'], df['Not Hispanic or Latino p'])
plt.title('Not Hispanic or Latino')
plt.xlabel('evictions proportion')
plt.ylabel('Not Hispanic or Latino proportion')
# Out:
# Text(0, 0.5, 'Not Hispanic or Latino proportion')

# %%
plt.scatter(df['Normalize'], df['Not Hispanic or Latino White alone p'])
plt.title('Not Hispanic or Latino White alone')
plt.xlabel('evictions proportion')
plt.ylabel('Not Hispanic or Latino White alone proportion')
# Out:
# Text(0, 0.5, 'Not Hispanic or Latino White alone proportion')

# %%
plt.scatter(df['Normalize'], df['Not Hispanic or Latino Black or African American alone p'])
plt.title('Not Hispanic or Latino Black or African American alone')
plt.xlabel('evictions proportion')
plt.ylabel('Not Hispanic or Latino Black or African American alone proportion')
# Out:
# Text(0, 0.5, 'Not Hispanic or Latino Black or African American alone proportion')

# %%
plt.scatter(df['Normalize'], df['Not Hispanic or Latino Asian alone p'])
plt.title('Not Hispanic or Latino Asian alone')
plt.xlabel('evictions proportion')
plt.ylabel('Not Hispanic or Latino Asian alone proportion')
# Out:
# Text(0, 0.5, 'Not Hispanic or Latino Asian alone proportion')

# %%
plt.scatter(df['Normalize'], df['Not Hispanic or Latino others p'])
plt.title('Not Hispanic or Latino others')
plt.xlabel('evictions proportion')
plt.ylabel('Not Hispanic or Latino others proportion')
# Out:
# Text(0, 0.5, 'Not Hispanic or Latino others proportion')

# %%
plt.scatter(df['Normalize'], df['Hispanic or Latino p'])
plt.title('Hispanic or Latino')
plt.xlabel('evictions proportion')
plt.ylabel('Hispanic or Latino proportion')
# Out:
# Text(0, 0.5, 'Hispanic or Latino proportion')

# %%
plt.scatter(df['Normalize'], df['Hispanic or Latino White alone p'])
plt.title('Hispanic or Latino White alone')
plt.xlabel('evictions proportion')
plt.ylabel('Hispanic or Latino White alone proportion')
# Out:
# Text(0, 0.5, 'Hispanic or Latino White alone proportion')

# %%
plt.scatter(df['Normalize'], df['Hispanic or Latino Black or African American alone p'])
plt.title('Hispanic or Latino Black or African American alone')
plt.xlabel('evictions proportion')
plt.ylabel('Hispanic or Latino Black or African American alone proportion')
# Out:
# Text(0, 0.5, 'Hispanic or Latino Black or African American alone proportion')

# %%
plt.scatter(df['Normalize'], df['Hispanic or Latino other p'])
plt.title('Hispanic or Latino other')
plt.xlabel('evictions proportion')
plt.ylabel('Hispanic or Latino other proportion')
# Out:
# Text(0, 0.5, 'Hispanic or Latino other proportion')
